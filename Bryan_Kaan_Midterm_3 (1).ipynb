# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("file:///Users/DeLaLuna/Downloads/concat_12_22.csv")

# %%
df = df.replace(',', '', regex=True)

# %%
df = df.drop('level_0',axis =1)

# %%
df = df.drop('index',axis =1)

# %%
# Assuming 'df' is already defined

filtered_df = df[df['Year'] == 2018]
filtered_df
# Out:
#       Year       District                                Location  Total  \
# 900   2018          Mitte                          Tiergarten Süd   5815
# 901   2018          Mitte                       Regierungsviertel   6860
# 902   2018          Mitte                          Alexanderplatz  19391
# 903   2018          Mitte                       Brunnenstraße Süd   4276
# 904   2018          Mitte                             Moabit West   6909
# ...    ...            ...                                     ...    ...
# 1045  2018  Reinickendorf  Nord 2 - Waidmannslust/Wittenau/Lübars   3521
# 1046  2018  Reinickendorf               MV 1 - Märkisches Viertel   3721
# 1047  2018  Reinickendorf                 MV 2 - Rollbergsiedlung    943
# 1048  2018  Reinickendorf      West 3 - Borsigwalde/Freie Scholle   1403
# 1049  2018  Reinickendorf            Bezirk (Rd) nicht zuzuordnen   1436
#
#       Robbery  Street_robbery  Injury  Agg_assault  Threat  Theft  Car  \
# 900        70              58     416          125     103   2540   17
# 901        34              16     519          110     114   3883   15
# 902       130              80    1531          366     309  10144   68
# 903        26              14     286           60      69   1817   47
# 904        71              38     653          164     215   2470   37
# ...       ...             ...     ...          ...     ...    ...  ...
# 1045       25              11     375           98     144   1168   35
# 1046       44              22     464          101     184   1135   76
# 1047        5               2     102           21      51    298    7
# 1048        6               3      94           21      50    506   28
# 1049       12              10     100           21      38    736   12
#
#       From_car  Bike  Burglary  Fire  Arson  Damage  Graffiti  Drugs  Local  \
# 900        274   310        39    14      3     284        42    273   1247
# 901        199   372        35     6      1     407       159    133    857
# 902        580   880       133    26      6    1036       333    971   2798
# 903        153   314        56     9      6     442       218     69    690
# 904        398   447        83    29     12     496        99    435   1262
# ...        ...   ...       ...   ...    ...     ...       ...    ...    ...
# 1045       168   132        97    11      3     311        83     95    765
# 1046       257    69        34    30      8     269        15     95    918
# 1047        54    24        19     2      0     107        29     18    204
# 1048       121    59        55     4      3     136        32     18    267
# 1049       136    52         1     5      2      63         2     33    213
#
#       City_population  Larceny_type  Property_damage_type  \
# 900           3552000          3141                   326
# 901           3552000          4469                   566
# 902           3552000         11672                  1369
# 903           3552000          2331                   660
# 904           3552000          3352                   595
# ...               ...           ...                   ...
# 1045          3552000          1503                   394
# 1046          3552000          1537                   284
# 1047          3552000           383                   136
# 1048          3552000           714                   168
# 1049          3552000           936                    65
#
#       Violent_crimes_type  Drugs_type  Pyro_type  Injury_type
# 900                   356         273         17          416
# 901                   274         133          7          519
# 902                   885         971         32         1531
# 903                   169          69         15          286
# 904                   488         435         41          653
# ...                   ...         ...        ...          ...
# 1045                  278          95         14          375
# 1046                  351          95         38          464
# 1047                   79          18          2          102
# 1048                   80          18          7           94
# 1049                   81          33          7          100
#
# [150 rows x 27 columns]

# %%
df
# Out:
#       Year       District                                Location  Total  \
# 0     2012          Mitte                          Tiergarten Süd   5333
# 1     2012          Mitte                       Regierungsviertel   6046
# 2     2012          Mitte                          Alexanderplatz  19314
# 3     2012          Mitte                       Brunnenstraße Süd   4712
# 4     2012          Mitte                             Moabit West   6960
# ...    ...            ...                                     ...    ...
# 1660  2022  Reinickendorf  Nord 2 - Waidmannslust/Wittenau/Lübars  17053
# 1661  2022  Reinickendorf                       Rollbergesiedlung   9215
# 1662  2022  Reinickendorf                                 MV Nord   8432
# 1663  2022  Reinickendorf                                  MV Süd   6320
# 1664  2022  Reinickendorf            Bezirk (Rd) nicht zuzuordnen  10191
#
#       Robbery  Street_robbery  Injury  Agg_assault  Threat  Theft  Car  \
# 0          70              46     586          194     118   2263   18
# 1          65              29     474          123     142   3203   10
# 2         242             136    1541          454     304   8988   81
# 3          52              25     254           60      66   1916   86
# 4         130              51     629          185     199   2470   94
# ...       ...             ...     ...          ...     ...    ...  ...
# 1660       78              53    1174          298     528   4234  137
# 1661       76              65     757          151     552   3753  162
# 1662       70              52    1305          329     595   2914  107
# 1663       80              43     790          130     623   1841   65
# 1664       85              52    1029          254     546   3773  124
#
#       From_car  Bike  Burglary  Fire  Arson  Damage  Graffiti  Drugs  Local  \
# 0          328   120        68    16      4     273        26    171   1032
# 1          307   170        37    10      4     380       124     98    870
# 2          792   822       275    49     27    1538       522    435   3108
# 3          192   396       131    14      5     428       122    213    752
# 4          410   325       161    42     22     516        64    259   1403
# ...        ...   ...       ...   ...    ...     ...       ...    ...    ...
# 1660       727   447       221    47     28     882       255    224   2668
# 1661       606   292       151    76     22     941        32    130   2401
# 1662       521   259        67   118     30     839        26    170   2899
# 1663       420   196       167    43     14     609        29    130   2131
# 1664       709   399       169    76     29     864       101    241   2478
#
#       City_population  Larceny_type  Property_damage_type  \
# 0             3476000          2729                   299
# 1             3476000          3690                   504
# 2             3476000         10683                  2060
# 3             3476000          2590                   550
# 4             3476000          3299                   580
# ...               ...           ...                   ...
# 1660          3571000          5545                  1137
# 1661          3571000          4813                   973
# 1662          3571000          3801                   865
# 1663          3571000          2522                   638
# 1664          3571000          5005                   965
#
#       Violent_crimes_type  Drugs_type  Pyro_type  Injury_type
# 0                     428         171         20          586
# 1                     359          98         14          474
# 2                    1136         435         76         1541
# 3                     203         213         19          254
# 4                     565         259         64          629
# ...                   ...         ...        ...          ...
# 1660                  957         224         75         1174
# 1661                  844         130         98          757
# 1662                 1046         170        148         1305
# 1663                  876         130         57          790
# 1664                  937         241        105         1029
#
# [1665 rows x 27 columns]

# %%
df.to_csv('df.csv', index=False)

# %%
#dfs = [df,df_20,df_21,df_22]
concat_12_22 = pd.concat(dfs,axis=0)

# %%
#concat_12_22
# Out:
#      Year       District                                Location   Total  \
# 0    2012          Mitte                          Tiergarten Süd    5333
# 1    2012          Mitte                       Regierungsviertel    6046
# 2    2012          Mitte                          Alexanderplatz   19314
# 3    2012          Mitte                       Brunnenstraße Süd    4712
# 4    2012          Mitte                             Moabit West    6960
# ..    ...            ...                                     ...     ...
# 150  2022  Reinickendorf  Nord 2 - Waidmannslust/Wittenau/Lübars  17,053
# 151  2022  Reinickendorf                       Rollbergesiedlung   9,215
# 152  2022  Reinickendorf                                 MV Nord   8,432
# 153  2022  Reinickendorf                                  MV Süd   6,320
# 154  2022  Reinickendorf           Bezirk (Rd), nicht zuzuordnen  10,191
#
#      Robbery  Street_robbery Injury Agg_assault Threat  Theft  Car From_car  \
# 0         70              46    586         194    118   2263   18      328
# 1         65              29    474         123    142   3203   10      307
# 2        242             136   1541         454    304   8988   81      792
# 3         52              25    254          60     66   1916   86      192
# 4        130              51    629         185    199   2470   94      410
# ..       ...             ...    ...         ...    ...    ...  ...      ...
# 150       78              53  1,174         298    528  4,234  137      727
# 151       76              65    757         151    552  3,753  162      606
# 152       70              52  1,305         329    595  2,914  107      521
# 153       80              43    790         130    623  1,841   65      420
# 154       85              52  1,029         254    546  3,773  124      709
#
#     Bike  Burglary  Fire  Arson Damage Graffiti Drugs  Local
# 0    120        68    16      4    273       26   171   1032
# 1    170        37    10      4    380      124    98    870
# 2    822       275    49     27   1538      522   435   3108
# 3    396       131    14      5    428      122   213    752
# 4    325       161    42     22    516       64   259   1403
# ..   ...       ...   ...    ...    ...      ...   ...    ...
# 150  447       221    47     28    882      255   224  2,668
# 151  292       151    76     22    941       32   130  2,401
# 152  259        67   118     30    839       26   170  2,899
# 153  196       167    43     14    609       29   130  2,131
# 154  399       169    76     29    864      101   241  2,478
#
# [1665 rows x 20 columns]

# %%
#concat_12_22.reset_index(inplace=True)
concat_12_22
# Out:
#       index  Year       District                                Location  \
# 0         0  2012          Mitte                          Tiergarten Süd
# 1         1  2012          Mitte                       Regierungsviertel
# 2         2  2012          Mitte                          Alexanderplatz
# 3         3  2012          Mitte                       Brunnenstraße Süd
# 4         4  2012          Mitte                             Moabit West
# ...     ...   ...            ...                                     ...
# 1660    150  2022  Reinickendorf  Nord 2 - Waidmannslust/Wittenau/Lübars
# 1661    151  2022  Reinickendorf                       Rollbergesiedlung
# 1662    152  2022  Reinickendorf                                 MV Nord
# 1663    153  2022  Reinickendorf                                  MV Süd
# 1664    154  2022  Reinickendorf           Bezirk (Rd), nicht zuzuordnen
#
#        Total  Robbery  Street_robbery Injury Agg_assault Threat  Theft  Car  \
# 0       5333       70              46    586         194    118   2263   18
# 1       6046       65              29    474         123    142   3203   10
# 2      19314      242             136   1541         454    304   8988   81
# 3       4712       52              25    254          60     66   1916   86
# 4       6960      130              51    629         185    199   2470   94
# ...      ...      ...             ...    ...         ...    ...    ...  ...
# 1660  17,053       78              53  1,174         298    528  4,234  137
# 1661   9,215       76              65    757         151    552  3,753  162
# 1662   8,432       70              52  1,305         329    595  2,914  107
# 1663   6,320       80              43    790         130    623  1,841   65
# 1664  10,191       85              52  1,029         254    546  3,773  124
#
#      From_car Bike  Burglary  Fire  Arson Damage Graffiti Drugs  Local
# 0         328  120        68    16      4    273       26   171   1032
# 1         307  170        37    10      4    380      124    98    870
# 2         792  822       275    49     27   1538      522   435   3108
# 3         192  396       131    14      5    428      122   213    752
# 4         410  325       161    42     22    516       64   259   1403
# ...       ...  ...       ...   ...    ...    ...      ...   ...    ...
# 1660      727  447       221    47     28    882      255   224  2,668
# 1661      606  292       151    76     22    941       32   130  2,401
# 1662      521  259        67   118     30    839       26   170  2,899
# 1663      420  196       167    43     14    609       29   130  2,131
# 1664      709  399       169    76     29    864      101   241  2,478
#
# [1665 rows x 21 columns]

# %%
#concat_12_22.to_csv("concat_12_22.csv", index = False)

# %%
df['City_population'] = np.nan

# %%
df.loc[df['Year'] == 2012, 'City_population'] = 3476000
df.loc[df['Year'] == 2013, 'City_population'] = 3488000
df.loc[df['Year'] == 2014, 'City_population'] = 3501000
df.loc[df['Year'] == 2015, 'City_population'] = 3514000
df.loc[df['Year'] == 2016, 'City_population'] = 3526000
df.loc[df['Year'] == 2017, 'City_population'] = 3539000
df.loc[df['Year'] == 2018, 'City_population'] = 3552000
df.loc[df['Year'] == 2019, 'City_population'] = 3557000
df.loc[df['Year'] == 2020, 'City_population'] = 3562000
df.loc[df['Year'] == 2021, 'City_population'] = 3567000
df.loc[df['Year'] == 2022, 'City_population'] = 3571000
df['City_population'] = df['City_population'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1665 entries, 0 to 1664
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             1665 non-null   int64
#  1   District         1665 non-null   object
#  2   Location         1665 non-null   object
#  3   Total            1665 non-null   object
#  4   Robbery          1665 non-null   int64
#  5   Street_robbery   1665 non-null   int64
#  6   Injury           1665 non-null   Int64
#  7   Agg_assault      1665 non-null   Int64
#  8   Threat           1665 non-null   Int64
#  9   Theft            1665 non-null   Int64
#  10  Car              1665 non-null   int64
#  11  From_car         1665 non-null   Int64
#  12  Bike             1665 non-null   Int64
#  13  Burglary         1665 non-null   int64
#  14  Fire             1665 non-null   int64
#  15  Arson            1665 non-null   int64
#  16  Damage           1665 non-null   Int64
#  17  Graffiti         1665 non-null   Int64
#  18  Drugs            1665 non-null   Int64
#  19  Local            1665 non-null   Int64
#  20  City_population  1665 non-null   int64
# dtypes: Int64(10), int64(8), object(3)
# memory usage: 289.5+ KB

# %%
columns_to_convert = ['Injury', 'Agg_assault', 'Threat', 'Total', 'Theft', 'From_car', 'Bike', 'Damage', 'Graffiti', 'Drugs', 'Local']

for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')

# %%
df['Larceny_type'] = df['Theft'] + df['Car'] + df['From_car'] + df['Bike']
df['Property_damage_type'] = df['Damage'] + df['Graffiti']
df['Violent_crimes_type'] = df['Robbery'] + df['Street_robbery'] + df['Threat'] + df['Agg_assault']
df['Drugs_type'] = df['Drugs']
df['Pyro_type'] = df['Arson'] + df['Fire']
df['Injury_type'] = df['Injury']

# %%
columns_to_sum = ['Larceny_type', 'Property_damage_type', 'Violent_crimes_type', 'Drugs_type', 'Pyro_type', 'Injury_type']
sum_per_year = df.groupby('Year')[columns_to_sum].sum()
print(sum_per_year)
# Out:
#       Larceny_type  Property_damage_type  Violent_crimes_type  Drugs_type  \
# Year
# 2012        269411                 59652                34397       11687
# 2013        289086                 52749                33803       12746
# 2014        303050                 48844                32059       12878
# 2015        324693                 48312                31156       15176
# 2016        327148                 50783                31589       14407
# 2017        289252                 51413                30549       15503
# 2018        274283                 48986                31240       16700
# 2019        260431                 52621                32380       18334
# 2020        977703                220782               128690       73672
# 2021        907373                209825               127621       66436
# 2022       1039251                205957               150117       60647
#
#       Pyro_type  Injury_type
# Year
# 2012       3418        42153
# 2013       3533        41461
# 2014       3230        39190
# 2015       2937        39312
# 2016       3561        41339
# 2017       3082        42283
# 2018       3220        42828
# 2019       3746        43035
# 2020      14682       167296
# 2021      14963       150921
# 2022      16573       169798

# %%
total_per_year = df.groupby('Year')['Total'].sum()
print('Total Crimes',total_per_year)
# Out:
# Total Crimes Year
# 2012     534475
# 2013     546004
# 2014     549100
# 2015     573611
# 2016     580387
# 2017     535681
# 2018     522588
# 2019     520086
# 2020    1758171
# 2021    1677873
# 2022    1783433
# Name: Total, dtype: Int64

# %%
#find overall total per district and rank in descending order

district_totals = df.groupby('District')[df.columns[4:19]].sum().sum(axis=1)
district_totals = district_totals.sort_values(ascending=False)
print(district_totals)

#Kaan added the plot, just to put on the presentation 
plt.figure(figsize=(10, 6))
district_totals.plot(kind='bar')
plt.xlabel('District')
plt.ylabel('Total_Crime')
plt.title('District Totals')

plt.show()
# Out:
# District
# Mitte                         1174206.0
# Friedrichshain-Kreuzberg       922472.0
# Charlottenburg-Wilmersdorf     816176.0
# Pankow                         794033.0
# Neukölln                       778480.0
# Tempelhof-Schöneberg           762117.0
# Treptow-Köpenick               726726.0
# Lichtenberg                    602254.0
# Reinickendorf                  513569.0
# Spandau                        440753.0
# Steglitz-Zehlendorf            406812.0
# Marzahn-Hellersdorf            406158.0
# dtype: float64

# %%
print(concat_12_22['City_population'].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1665 entries, 0 to 1664
# Series name: City_population
# Non-Null Count  Dtype
# --------------  -----
# 1665 non-null   int64
# dtypes: int64(1)
# memory usage: 13.1 KB
# None

# %%
concat_12_22['Total'] = pd.to_numeric(concat_12_22['Total'], errors='coerce').fillna(0).astype(int)

# %%
for column in columns_to_convert:
    concat_12_22[column] = pd.to_numeric(concat_12_22[column].str.replace(',', ''), errors='coerce')
    concat_12_22[column] = concat_12_22[column].fillna(0).astype(int)

# %%
concat_12_22
# Out:
#       index  Year       District                                Location  \
# 0         0  2012          Mitte                          Tiergarten Süd
# 1         1  2012          Mitte                       Regierungsviertel
# 2         2  2012          Mitte                          Alexanderplatz
# 3         3  2012          Mitte                       Brunnenstraße Süd
# 4         4  2012          Mitte                             Moabit West
# ...     ...   ...            ...                                     ...
# 1660    150  2022  Reinickendorf  Nord 2 - Waidmannslust/Wittenau/Lübars
# 1661    151  2022  Reinickendorf                       Rollbergesiedlung
# 1662    152  2022  Reinickendorf                                 MV Nord
# 1663    153  2022  Reinickendorf                                  MV Süd
# 1664    154  2022  Reinickendorf           Bezirk (Rd), nicht zuzuordnen
#
#       Total  Robbery  Street_robbery  Injury  Agg_assault  Threat  Theft  Car  \
# 0      5333       70              46       0            0       0      0   18
# 1      6046       65              29       0            0       0      0   10
# 2     19314      242             136       0            0       0      0   81
# 3      4712       52              25       0            0       0      0   86
# 4      6960      130              51       0            0       0      0   94
# ...     ...      ...             ...     ...          ...     ...    ...  ...
# 1660      0       78              53    1174          298     528   4234  137
# 1661      0       76              65     757          151     552   3753  162
# 1662      0       70              52    1305          329     595   2914  107
# 1663      0       80              43     790          130     623   1841   65
# 1664      0       85              52    1029          254     546   3773  124
#
#       From_car  Bike  Burglary  Fire  Arson  Damage  Graffiti  Drugs  Local  \
# 0            0     0        68    16      4       0         0      0      0
# 1            0     0        37    10      4       0         0      0      0
# 2            0     0       275    49     27       0         0      0      0
# 3            0     0       131    14      5       0         0      0      0
# 4            0     0       161    42     22       0         0      0      0
# ...        ...   ...       ...   ...    ...     ...       ...    ...    ...
# 1660       727   447       221    47     28     882       255    224   2668
# 1661       606   292       151    76     22     941        32    130   2401
# 1662       521   259        67   118     30     839        26    170   2899
# 1663       420   196       167    43     14     609        29    130   2131
# 1664       709   399       169    76     29     864       101    241   2478
#
#       City_population  Crimes per 1000
# 0             3476000                2
# 1             3476000                2
# 2             3476000                6
# 3             3476000                2
# 4             3476000                3
# ...               ...              ...
# 1660          3571000                0
# 1661          3571000                0
# 1662          3571000                0
# 1663          3571000                0
# 1664          3571000                0
#
# [1665 rows x 23 columns]

# %%
import pandas as pd
import math

concat_12_22['City_population'] = pd.to_numeric(concat_12_22['City_population'], errors='coerce')
concat_12_22['Total'] = pd.to_numeric(concat_12_22['Total'], errors='coerce')

concat_12_22['City_population'] = concat_12_22.groupby('Year')['City_population'].transform('first')
concat_12_22['Crimes per 1000'] = (concat_12_22['Total'] / concat_12_22['City_population']) * 1000
concat_12_22['Crimes per 1000'] = concat_12_22['Crimes per 1000'].apply(math.ceil)
crime_per_capita = concat_12_22[['Year', 'City_population', 'Total', 'Crimes per 1000']].drop_duplicates('Year')
print(crime_per_capita)
# Out:
#       Year  City_population  Total  Crimes per 1000
# 0     2012          3476000   5333                2
# 150   2013          3488000   5610                2
# 300   2014          3501000   5510                2
# 450   2015          3514000   5740                2
# 600   2016          3526000   5235                2
# 750   2017          3539000   5884                2
# 900   2018          3552000   5815                2
# 1050  2019          3557000   5169                2
# 1200  2020          3562000      0                0
# 1355  2021          3567000      0                0
# 1510  2022          3571000      0                0

# %%
concat_12_22["Total"] = concat_12_22.groupby([""])
